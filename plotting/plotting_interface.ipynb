# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
#read csvfile output of project
df1 = pd.read_csv('progress-BNN.csv')

# %%
#read csvfile output of project
df2 = pd.read_csv('progress-GNN.csv')

# %%
df1
# Out:
#       epoch  batch      loss  accuracy
# 0       1.0    0.0  2.487955       NaN
# 1       1.0  100.0  2.413532       NaN
# 2       1.0  200.0  2.420453       NaN
# 3       1.0  300.0  2.350816       NaN
# 4       1.0    NaN       NaN    0.1303
# ...     ...    ...       ...       ...
# 1095  220.0    0.0  0.876946       NaN
# 1096  220.0  100.0  0.804616       NaN
# 1097  220.0  200.0  0.926478       NaN
# 1098  220.0  300.0  0.907484       NaN
# 1099  220.0    NaN       NaN    0.6603
#
# [1100 rows x 4 columns]

# %%
df_loss1 = df1.drop('accuracy', 1)
df_loss1 = df_loss1.dropna()

df_acc1 = df1.drop(['loss', 'batch'], 1)
df_acc1 = df_acc1.dropna()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   after removing the cwd from sys.path.

# %%
df_loss2 = df2.drop('accuracy', 1)
df_loss2 = df_loss2.dropna()

df_acc2 = df2.drop(['loss', 'batch'], 1)
df_acc2 = df_acc2.dropna()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   after removing the cwd from sys.path.

# %%
fig, axs = plt.subplots(2, 1)
fig.set_size_inches(10,7)


#axs[0].set_title('Loss')
axs[0].plot(df_loss1['epoch'], df_loss1['loss'],label='BN Centralized',color="#06C2AC")
axs[0].plot(df_loss2['epoch'],df_loss2["loss"],color="#8C000F",label='GN Centralized')
axs[0].legend(prop={'size': 18})
axs[0].set_ylabel('Loss', fontsize=25)

axs[0].tick_params(axis='x',labelsize=15)
axs[0].tick_params(axis='y',labelsize=15)
#axs[1].set_title('Accuracy')



axs[0].grid(True);
axs[1].set_ylim((0,100))
axs[1].plot(df_acc1['epoch'], df_acc1['accuracy'] * 100, color="#06C2AC",label='BN  Centralized')
axs[1].plot(df_acc2['epoch'], df_acc2['accuracy'] * 100,color="#8C000F",label='GN  Centralized')
axs[1].legend(prop={'size': 18},loc='lower right')
axs[1].set_ylabel('Accuracy', fontsize=25)
axs[1].set_xlabel('Epochs', fontsize=25)
axs[1].tick_params(axis='x',labelsize=15)
axs[1].tick_params(axis='y',labelsize=15)
fig.tight_layout()
axs[1].grid(True);

# %%
df11 = pd.read_csv('fed-progress-iid-BN.csv')

# %%
df_loss11 = df11.drop('accuracy', 1)
df_loss11 = df_loss11.dropna()

df_acc11 = df11.drop(['loss', 'devices'], 1)
df_acc11 = df_acc11.dropna()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   after removing the cwd from sys.path.

# %%
df22 = pd.read_csv('fed-progress-iid-GN.csv')

# %%
df_loss22 = df22.drop('accuracy', 1)
df_loss22 = df_loss22.dropna()

df_acc22 = df22.drop(['loss', 'devices'], 1)
df_acc22 = df_acc22.dropna()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   after removing the cwd from sys.path.

# %%
df33 = pd.read_csv('progress-niid-BNN.csv')

# %%
df_loss33 = df33.drop('accuracy', 1)
df_loss33 = df_loss33.dropna()

df_acc33 = df33.drop(['loss', 'devices'], 1)
df_acc33 = df_acc33.dropna()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   after removing the cwd from sys.path.

# %%
df44 = pd.read_csv('progress-niid-GNN.csv')

# %%
df_loss44 = df44.drop('accuracy', 1)
df_loss44 = df_loss44.dropna()

df_acc44 = df44.drop(['loss', 'devices'], 1)
df_acc44 = df_acc44.dropna()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   after removing the cwd from sys.path.

# %%
fig, axs = plt.subplots(2, 1)
fig.set_size_inches(10,15)


#axs[0].set_title('Loss')
axs[0].plot(df_loss11['epoch'], df_loss11['loss'],label='BN iid',color="#380282")
axs[0].plot(df_loss22['epoch'],df_loss22["loss"],color="#EF4026",label='GN iid')
axs[0].plot(df_loss33['epoch'],df_loss33["loss"],color="#15B01A",label='BN Non-iid', linestyle='--')
axs[0].plot(df_loss44['epoch'],df_loss44["loss"],color="#069AF3",label='GN Non-iid', linestyle='--')
axs[0].legend(prop={'size': 18})
axs[0].set_ylabel('Loss', fontsize=25)
axs[0].tick_params(axis='x',labelsize=15)
axs[0].tick_params(axis='y',labelsize=15)
axs[0].grid(True);



axs[1].set_ylim((0,100))
axs[1].plot(df_acc11['epoch'], df_acc11['accuracy'] * 100, color="#380282",label='BN  iid')
axs[1].plot(df_acc22['epoch'], df_acc22['accuracy'] * 100,color="#EF4026",label='GN  iid')
axs[1].plot(df_acc33['epoch'], df_acc33['accuracy'] * 100, color="#15B01A",label='BN  Non-iid', linestyle='--')
axs[1].plot(df_acc44['epoch'], df_acc44['accuracy'] * 100,color="#069AF3",label='GN  Non-iid', linestyle='--')
axs[1].legend(prop={'size': 18},loc='upper right')
axs[1].set_ylabel('Accuracy', fontsize=25)
axs[1].set_xlabel('Epochs', fontsize=25)
axs[1].tick_params(axis='x',labelsize=15)
axs[1].tick_params(axis='y',labelsize=15)
fig.tight_layout()
axs[1].grid(True);

# %%
df_acc111 = pd.read_csv('FedAVG BN.csv')

# %%
df_acc222 = pd.read_csv('scaffold BN.csv')

# %%
df_acc333 = pd.read_csv('fedAVG GN.csv')

# %%
df_acc444 = pd.read_csv('scaffold GN.csv')

# %%
fig, axs = plt.subplots(2, 1)
fig.set_size_inches(10,7)



axs[0].plot(df_acc111['epoch'], df_acc111['accuracy'] , color="#380282",label='BN  FedAvg', linestyle='--')
axs[0].plot(df_acc222['epoch'], df_acc222['accuracy'] ,color="#380282",label='BN  SCAFFOLD')
axs[0].plot(df_acc333['epoch'], df_acc333['accuracy'] , color="#15B01A",label='GN  FedAvg', linestyle='--')
axs[0].plot(df_acc444['epoch'], df_acc444['accuracy'],color="#15B01A",label='GN  SCAFFOLD')
axs[0].legend(prop={'size': 16})
axs[0].set_ylabel('accuracy', fontsize=25)
axs[0].tick_params(axis='x',labelsize=15)
axs[0].tick_params(axis='y',labelsize=15)
axs[0].set_xlabel('Epochs', fontsize=25)
axs[0].grid(True);



axs[1].set_xlim((0,100))
axs[1].plot(df_acc111['epoch'], df_acc111['accuracy'] , color="#380282",label='BN  AVG', linestyle='--')
axs[1].plot(df_acc222['epoch'], df_acc222['accuracy'] ,color="#EF4026",label='BN  scaffold')
axs[1].plot(df_acc333['epoch'], df_acc333['accuracy'] , color="#15B01A",label='gn  avg', linestyle='--')
axs[1].plot(df_acc444['epoch'], df_acc444['accuracy'],color="#069AF3",label='GN  scaffold',)
axs[1].legend(prop={'size': 18},loc='upper right')
axs[1].set_ylabel('Accuracy', fontsize=25)
axs[1].set_xlabel('Epochs', fontsize=25)
axs[1].tick_params(axis='x',labelsize=15)
axs[1].tick_params(axis='y',labelsize=15)
fig.tight_layout()
axs[1].grid(True);

# %%
df1111 = pd.read_csv('iid BN - iid BN.csv')

# %%
df2222 = pd.read_csv('iid GN - iid GN.csv')

# %%
df3333 = pd.read_csv('noniid BN - noniid BN.csv')

# %%
df4444 = pd.read_csv('noniid GN - noniid GN.csv')

# %%
fig, axs = plt.subplots(2, 1)
fig.set_size_inches(10,10)



axs[0].plot(df1111['epochs'], df1111['loss'] , color="#380282",label='BN iid', linestyle='--')
axs[0].plot(df2222['epochs'], df2222['loss'] ,color="#380282",label='gn iid')
axs[0].plot(df3333['epochs'], df3333['loss'] , color="#15B01A",label='bn  noniid', linestyle='--')
axs[0].plot(df4444['epochs'], df4444['loss'],color="#15B01A",label='GN  noniid')
axs[0].legend(prop={'size': 16})
axs[0].set_ylabel('Loss', fontsize=25)
axs[0].tick_params(axis='x',labelsize=15)
axs[0].tick_params(axis='y',labelsize=15)
axs[0].set_xlabel('Epochs', fontsize=25)
axs[0].grid(True);




axs[1].plot(df1111['epochs'], df1111['accuracy'] , color="orange",label='BN iid')
axs[1].plot(df2222['epochs'], df2222['accuracy'] ,color="darkblue",label='GN iid')
axs[1].plot(df3333['epochs'], df3333['accuracy'] , color="orange",label='BN  Non-iid', linestyle='--')
axs[1].plot(df4444['epochs'], df4444['accuracy'],color="darkblue",label='GN  Non-iid', linestyle='--')
axs[1].legend(prop={'size': 18},loc='upper left')
axs[1].set_ylabel('Accuracy', fontsize=25)
axs[1].set_xlabel('Epochs', fontsize=25)
axs[1].tick_params(axis='x',labelsize=15)
axs[1].tick_params(axis='y',labelsize=15)
fig.tight_layout()
axs[1].grid(True);
